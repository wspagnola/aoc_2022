# %%
with open('data/input_test_2022-12-10.txt', encoding = 'utf-8-sig') as f:
    lines = f.readlines()
    
text = [ line.strip('\n') for line in lines]
steps = [x.split() for x in text]
steps
# Out:
# [['addx', '15'],
#  ['addx', '-11'],
#  ['addx', '6'],
#  ['addx', '-3'],
#  ['addx', '5'],
#  ['addx', '-1'],
#  ['addx', '-8'],
#  ['addx', '13'],
#  ['addx', '4'],
#  ['noop'],
#  ['addx', '-1'],
#  ['addx', '5'],
#  ['addx', '-1'],
#  ['addx', '5'],
#  ['addx', '-1'],
#  ['addx', '5'],
#  ['addx', '-1'],
#  ['addx', '5'],
#  ['addx', '-1'],
#  ['addx', '-35'],
#  ['addx', '1'],
#  ['addx', '24'],
#  ['addx', '-19'],
#  ['addx', '1'],
#  ['addx', '16'],
#  ['addx', '-11'],
#  ['noop'],
#  ['noop'],
#  ['addx', '21'],
#  ['addx', '-15'],
#  ['noop'],
#  ['noop'],
#  ['addx', '-3'],
#  ['addx', '9'],
#  ['addx', '1'],
#  ['addx', '-3'],
#  ['addx', '8'],
#  ['addx', '1'],
#  ['addx', '5'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['addx', '-36'],
#  ['noop'],
#  ['addx', '1'],
#  ['addx', '7'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['addx', '2'],
#  ['addx', '6'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['addx', '1'],
#  ['noop'],
#  ['noop'],
#  ['addx', '7'],
#  ['addx', '1'],
#  ['noop'],
#  ['addx', '-13'],
#  ['addx', '13'],
#  ['addx', '7'],
#  ['noop'],
#  ['addx', '1'],
#  ['addx', '-33'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['addx', '2'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['addx', '8'],
#  ['noop'],
#  ['addx', '-1'],
#  ['addx', '2'],
#  ['addx', '1'],
#  ['noop'],
#  ['addx', '17'],
#  ['addx', '-9'],
#  ['addx', '1'],
#  ['addx', '1'],
#  ['addx', '-3'],
#  ['addx', '11'],
#  ['noop'],
#  ['noop'],
#  ['addx', '1'],
#  ['noop'],
#  ['addx', '1'],
#  ['noop'],
#  ['noop'],
#  ['addx', '-13'],
#  ['addx', '-19'],
#  ['addx', '1'],
#  ['addx', '3'],
#  ['addx', '26'],
#  ['addx', '-30'],
#  ['addx', '12'],
#  ['addx', '-1'],
#  ['addx', '3'],
#  ['addx', '1'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['addx', '-9'],
#  ['addx', '18'],
#  ['addx', '1'],
#  ['addx', '2'],
#  ['noop'],
#  ['noop'],
#  ['addx', '9'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  ['addx', '-1'],
#  ['addx', '2'],
#  ['addx', '-37'],
#  ['addx', '1'],
#  ['addx', '3'],
#  ['noop'],
#  ['addx', '15'],
#  ['addx', '-21'],
#  ['addx', '22'],
#  ['addx', '-6'],
#  ['addx', '1'],
#  ['noop'],
#  ['addx', '2'],
#  ['addx', '1'],
#  ['noop'],
#  ['addx', '-10'],
#  ['noop'],
#  ['noop'],
#  ['addx', '20'],
#  ['addx', '1'],
#  ['addx', '2'],
#  ['addx', '2'],
#  ['addx', '-6'],
#  ['addx', '-11'],
#  ['noop'],
#  ['noop'],
#  ['noop'],
#  []]

# %%
X = [1]
for i, x in enumerate(steps):
    print('i=', i)
    print('step=', x)
    if x[0] == 'addx':
      #  print(X[i])
        X.append(X[-1])
        X.append(int(x[1])+int(X[-1]))
       #print(X)
    else:
        X.append(X[-1])
X[19]*20
# Out:
# i= 0
# step= ['addx', '15']
# i= 1
# step= ['addx', '-11']
# i= 2
# step= ['addx', '6']
# i= 3
# step= ['addx', '-3']
# i= 4
# step= ['addx', '5']
# i= 5
# step= ['addx', '-1']
# i= 6
# step= ['addx', '-8']
# i= 7
# step= ['addx', '13']
# i= 8
# step= ['addx', '4']
# i= 9
# step= ['noop']
# i= 10
# step= ['addx', '-1']
# i= 11
# step= ['addx', '5']
# i= 12
# step= ['addx', '-1']
# i= 13
# step= ['addx', '5']
# i= 14
# step= ['addx', '-1']
# i= 15
# step= ['addx', '5']
# i= 16
# step= ['addx', '-1']
# i= 17
# step= ['addx', '5']
# i= 18
# step= ['addx', '-1']
# i= 19
# step= ['addx', '-35']
# i= 20
# step= ['addx', '1']
# i= 21
# step= ['addx', '24']
# i= 22
# step= ['addx', '-19']
# i= 23
# step= ['addx', '1']
# i= 24
# step= ['addx', '16']
# i= 25
# step= ['addx', '-11']
# i= 26
# step= ['noop']
# i= 27
# step= ['noop']
# i= 28
# step= ['addx', '21']
# i= 29
# step= ['addx', '-15']
# i= 30
# step= ['noop']
# i= 31
# step= ['noop']
# i= 32
# step= ['addx', '-3']
# i= 33
# step= ['addx', '9']
# i= 34
# step= ['addx', '1']
# i= 35
# step= ['addx', '-3']
# i= 36
# step= ['addx', '8']
# i= 37
# step= ['addx', '1']
# i= 38
# step= ['addx', '5']
# i= 39
# step= ['noop']
# i= 40
# step= ['noop']
# i= 41
# step= ['noop']
# i= 42
# step= ['noop']
# i= 43
# step= ['noop']
# i= 44
# step= ['addx', '-36']
# i= 45
# step= ['noop']
# i= 46
# step= ['addx', '1']
# i= 47
# step= ['addx', '7']
# i= 48
# step= ['noop']
# i= 49
# step= ['noop']
# i= 50
# step= ['noop']
# i= 51
# step= ['addx', '2']
# i= 52
# step= ['addx', '6']
# i= 53
# step= ['noop']
# i= 54
# step= ['noop']
# i= 55
# step= ['noop']
# i= 56
# step= ['noop']
# i= 57
# step= ['noop']
# i= 58
# step= ['addx', '1']
# i= 59
# step= ['noop']
# i= 60
# step= ['noop']
# i= 61
# step= ['addx', '7']
# i= 62
# step= ['addx', '1']
# i= 63
# step= ['noop']
# i= 64
# step= ['addx', '-13']
# i= 65
# step= ['addx', '13']
# i= 66
# step= ['addx', '7']
# i= 67
# step= ['noop']
# i= 68
# step= ['addx', '1']
# i= 69
# step= ['addx', '-33']
# i= 70
# step= ['noop']
# i= 71
# step= ['noop']
# i= 72
# step= ['noop']
# i= 73
# step= ['addx', '2']
# i= 74
# step= ['noop']
# i= 75
# step= ['noop']
# i= 76
# step= ['noop']
# i= 77
# step= ['addx', '8']
# i= 78
# step= ['noop']
# i= 79
# step= ['addx', '-1']
# i= 80
# step= ['addx', '2']
# i= 81
# step= ['addx', '1']
# i= 82
# step= ['noop']
# i= 83
# step= ['addx', '17']
# i= 84
# step= ['addx', '-9']
# i= 85
# step= ['addx', '1']
# i= 86
# step= ['addx', '1']
# i= 87
# step= ['addx', '-3']
# i= 88
# step= ['addx', '11']
# i= 89
# step= ['noop']
# i= 90
# step= ['noop']
# i= 91
# step= ['addx', '1']
# i= 92
# step= ['noop']
# i= 93
# step= ['addx', '1']
# i= 94
# step= ['noop']
# i= 95
# step= ['noop']
# i= 96
# step= ['addx', '-13']
# i= 97
# step= ['addx', '-19']
# i= 98
# step= ['addx', '1']
# i= 99
# step= ['addx', '3']
# i= 100
# step= ['addx', '26']
# i= 101
# step= ['addx', '-30']
# i= 102
# step= ['addx', '12']
# i= 103
# step= ['addx', '-1']
# i= 104
# step= ['addx', '3']
# i= 105
# step= ['addx', '1']
# i= 106
# step= ['noop']
# i= 107
# step= ['noop']
# i= 108
# step= ['noop']
# i= 109
# step= ['addx', '-9']
# i= 110
# step= ['addx', '18']
# i= 111
# step= ['addx', '1']
# i= 112
# step= ['addx', '2']
# i= 113
# step= ['noop']
# i= 114
# step= ['noop']
# i= 115
# step= ['addx', '9']
# i= 116
# step= ['noop']
# i= 117
# step= ['noop']
# i= 118
# step= ['noop']
# i= 119
# step= ['addx', '-1']
# i= 120
# step= ['addx', '2']
# i= 121
# step= ['addx', '-37']
# i= 122
# step= ['addx', '1']
# i= 123
# step= ['addx', '3']
# i= 124
# step= ['noop']
# i= 125
# step= ['addx', '15']
# i= 126
# step= ['addx', '-21']
# i= 127
# step= ['addx', '22']
# i= 128
# step= ['addx', '-6']
# i= 129
# step= ['addx', '1']
# i= 130
# step= ['noop']
# i= 131
# step= ['addx', '2']
# i= 132
# step= ['addx', '1']
# i= 133
# step= ['noop']
# i= 134
# step= ['addx', '-10']
# i= 135
# step= ['noop']
# i= 136
# step= ['noop']
# i= 137
# step= ['addx', '20']
# i= 138
# step= ['addx', '1']
# i= 139
# step= ['addx', '2']
# i= 140
# step= ['addx', '2']
# i= 141
# step= ['addx', '-6']
# i= 142
# step= ['addx', '-11']
# i= 143
# step= ['noop']
# i= 144
# step= ['noop']
# i= 145
# step= ['noop']
# i= 146
# step= []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-79ccb86b6e35> in <module>
#       3     print('i=', i)
#       4     print('step=', x)
# ----> 5     if x[0] == 'addx':
#       6       #  print(X[i])
#       7         X.append(X[-1])
#
# IndexError: list index out of range
